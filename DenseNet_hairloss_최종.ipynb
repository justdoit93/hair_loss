# %%
import pandas as pd

# CSV 파일을 DataFrame으로 가져오기
train_data = pd.read_csv('./train_df path 포함.csv')
train_data = pd.DataFrame(train_data)
train_data.head()
# Out:
#    Unnamed: 0                              image_id  \
# 0           0  0013_A2LEBJJDE00060O_1606550825417_3
# 1           1  0177_A2LEBJJDE00152B_1604650530904_6
# 2           2  0335_A2LEBJJDE00013X_1602916465540_6
# 3           3  0335_A2LEBJJDE000542_1605676381132_4
# 4           4  0425_A2LEBJJDE00079P_1605793927978_5
#
#                                image_file_name  미세각질  피지과다  모낭사이홍반  모낭홍반농포  \
# 0  0013_A2LEBJJDE00060O_1606550825417_3_TH.jpg     0     0       0       0
# 1  0177_A2LEBJJDE00152B_1604650530904_6_BH.jpg     0     0       0       0
# 2  0335_A2LEBJJDE00013X_1602916465540_6_BH.jpg     0     0       0       0
# 3  0335_A2LEBJJDE000542_1605676381132_4_LH.jpg     0     0       0       0
# 4  0425_A2LEBJJDE00079P_1605793927978_5_RH.jpg     0     0       0       0
#
#    비듬  탈모            where                                         image_path
# 0   0   0  [라벨]모낭사이홍반_0.양호  ./Training/[원천]모낭사이홍반_0.양호.zipfile/0013_A2LEBJ...
# 1   0   0  [라벨]모낭사이홍반_0.양호  ./Training/[원천]모낭사이홍반_0.양호.zipfile/0177_A2LEBJ...
# 2   0   0  [라벨]모낭사이홍반_0.양호  ./Training/[원천]모낭사이홍반_0.양호.zipfile/0335_A2LEBJ...
# 3   0   0  [라벨]모낭사이홍반_0.양호  ./Training/[원천]모낭사이홍반_0.양호.zipfile/0335_A2LEBJ...
# 4   0   0  [라벨]모낭사이홍반_0.양호  ./Training/[원천]모낭사이홍반_0.양호.zipfile/0425_A2LEBJ...

# %%
# test CSV 파일을 DataFrame으로 가져오기
test_data = pd.read_csv('./path포함_df.csv')
test_data = pd.DataFrame(test_data)
test_data.head()
# Out:
#    Unnamed: 0                              image_id  \
# 0           0  6995_A2LEBJJDE00104R_1606040549648_5
# 1           1  7027_A2LEBJJDE001117_1602922543531_2
# 2           2  7027_A2LEBJJDE001117_1602988151264_3
# 3           3  7027_A2LEBJJDE001117_1603609341639_3
# 4           4  7027_A2LEBJJDE001117_1603949553519_3
#
#                                image_file_name  미세각질  피지과다  모낭사이홍반  모낭홍반농포  \
# 0  6995_A2LEBJJDE00104R_1606040549648_5_RH.jpg     0     0       0       0
# 1  7027_A2LEBJJDE001117_1602922543531_2_TH.jpg     0     0       0       0
# 2  7027_A2LEBJJDE001117_1602988151264_3_TH.jpg     0     0       0       0
# 3  7027_A2LEBJJDE001117_1603609341639_3_TH.jpg     0     0       0       0
# 4  7027_A2LEBJJDE001117_1603949553519_3_TH.jpg     0     0       0       0
#
#    비듬  탈모            where                                         image_path
# 0   0   0  [라벨]모낭사이홍반_0.양호  ./Validation/[원천]모낭사이홍반_0.양호/6995_A2LEBJJDE001...
# 1   0   0  [라벨]모낭사이홍반_0.양호  ./Validation/[원천]모낭사이홍반_0.양호/7027_A2LEBJJDE001...
# 2   0   0  [라벨]모낭사이홍반_0.양호  ./Validation/[원천]모낭사이홍반_0.양호/7027_A2LEBJJDE001...
# 3   0   0  [라벨]모낭사이홍반_0.양호  ./Validation/[원천]모낭사이홍반_0.양호/7027_A2LEBJJDE001...
# 4   0   0  [라벨]모낭사이홍반_0.양호  ./Validation/[원천]모낭사이홍반_0.양호/7027_A2LEBJJDE001...

# %%
# image_path 수정
train_data['image_path'] = train_data['image_path'].str.replace('./Training', './data/Training')
train_data['image_path'] = train_data['image_path'].str.replace('.zipfile', '')
test_data['image_path'] = test_data['image_path'].str.replace('./Validation', './data/Validation')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_12808\1468559879.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['image_path'] = train_data['image_path'].str.replace('./Training', './data/Training')
# C:\Users\admin\AppData\Local\Temp\ipykernel_12808\1468559879.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['image_path'] = train_data['image_path'].str.replace('.zipfile', '')
# C:\Users\admin\AppData\Local\Temp\ipykernel_12808\1468559879.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['image_path'] = test_data['image_path'].str.replace('./Validation', './data/Validation')

# %%
# 탈모 데이터 확인
train_data[train_data['where'].str.contains('탈모')]
# Out:
#         Unnamed: 0                              image_id  \
# 93088        93088  0013_A2LEBJJDE00060O_1606550825417_3
# 93089        93089  0177_A2LEBJJDE00152B_1604650530904_6
# 93090        93090  0335_A2LEBJJDE00013X_1602916465540_6
# 93091        93091  0335_A2LEBJJDE000542_1605676381132_4
# 93092        93092  0425_A2LEBJJDE00079P_1605793927978_5
# ...            ...                                   ...
# 111596      111596  9887_A2LEBJJDE00066H_1605155133469_6
# 111597      111597  9905_A2LEBJJDE00042M_1602729142776_4
# 111598      111598  9905_A2LEBJJDE00042M_1602729347625_4
# 111599      111599  9905_A2LEBJJDE00042M_1604108127168_4
# 111600      111600  9905_A2LEBJJDE00042M_1606541098293_2
#
#                                     image_file_name  미세각질  피지과다  모낭사이홍반  \
# 93088   0013_A2LEBJJDE00060O_1606550825417_3_TH.jpg     0     0       0
# 93089   0177_A2LEBJJDE00152B_1604650530904_6_BH.jpg     0     0       0
# 93090   0335_A2LEBJJDE00013X_1602916465540_6_BH.jpg     0     0       0
# 93091   0335_A2LEBJJDE000542_1605676381132_4_LH.jpg     0     0       0
# 93092   0425_A2LEBJJDE00079P_1605793927978_5_RH.jpg     0     0       0
# ...                                             ...   ...   ...     ...
# 111596  9887_A2LEBJJDE00066H_1605155133469_6_BH.jpg     0     2       2
# 111597  9905_A2LEBJJDE00042M_1602729142776_4_LH.jpg     2     0       1
# 111598  9905_A2LEBJJDE00042M_1602729347625_4_LH.jpg     1     0       1
# 111599  9905_A2LEBJJDE00042M_1604108127168_4_LH.jpg     0     2       1
# 111600  9905_A2LEBJJDE00042M_1606541098293_2_TH.jpg     2     1       0
#
#         모낭홍반농포  비듬  탈모        where  \
# 93088        0   0   0  [라벨]탈모_0.양호
# 93089        0   0   0  [라벨]탈모_0.양호
# 93090        0   0   0  [라벨]탈모_0.양호
# 93091        0   0   0  [라벨]탈모_0.양호
# 93092        0   0   0  [라벨]탈모_0.양호
# ...        ...  ..  ..          ...
# 111596       0   0   3  [라벨]탈모_3.중증
# 111597       0   0   3  [라벨]탈모_3.중증
# 111598       0   1   3  [라벨]탈모_3.중증
# 111599       0   0   3  [라벨]탈모_3.중증
# 111600       0   0   3  [라벨]탈모_3.중증
#
#                                                image_path
# 93088   ./data/Training/[원천]탈모_0.양호/0013_A2LEBJJDE0006...
# 93089   ./data/Training/[원천]탈모_0.양호/0177_A2LEBJJDE0015...
# 93090   ./data/Training/[원천]탈모_0.양호/0335_A2LEBJJDE0001...
# 93091   ./data/Training/[원천]탈모_0.양호/0335_A2LEBJJDE0005...
# 93092   ./data/Training/[원천]탈모_0.양호/0425_A2LEBJJDE0007...
# ...                                                   ...
# 111596  ./data/Training/[원천]탈모_3.중증/9887_A2LEBJJDE0006...
# 111597  ./data/Training/[원천]탈모_3.중증/9905_A2LEBJJDE0004...
# 111598  ./data/Training/[원천]탈모_3.중증/9905_A2LEBJJDE0004...
# 111599  ./data/Training/[원천]탈모_3.중증/9905_A2LEBJJDE0004...
# 111600  ./data/Training/[원천]탈모_3.중증/9905_A2LEBJJDE0004...
#
# [18513 rows x 11 columns]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, TensorDataset
import os

from torchvision import utils
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image
import numpy as np
from torchsummary import summary
import time
import copy

# %%
train_data_hairLoss = train_data[train_data['where'].str.contains('탈모')]
test_data_hairLoss = test_data[test_data['where'].str.contains('탈모')]

# 이미지 파일 경로를 포함한 DataFrame 생성
train_path = train_data_hairLoss[['image_path']]

transform = transforms.Compose([
    transforms.Resize((256, 256)),  # 이미지 크기 조정
    transforms.ToTensor(),  # 이미지를 텐서로 변환
    transforms.Normalize(mean=[0.25, 0.25, 0.25], std=[0.1, 0.1, 0.1])  # 이미지 정규화
])

tensor_list_train = []
tensor_list_test = []
for image_path in train_path['image_path']:
    image = Image.open(image_path)
    tensor = transform(image)
    tensor_list_train.append(tensor)

image_tensors_train = torch.stack(tensor_list_train) #train데이터
    
# 이미지 파일 경로를 포함한 DataFrame 생성
test_path = test_data_hairLoss[['image_path']]

transform = transforms.Compose([
    transforms.Resize((256, 256)),  # 이미지 크기 조정
    transforms.ToTensor(),  # 이미지를 텐서로 변환
    transforms.Normalize(mean=[0.25, 0.25, 0.25], std=[0.1, 0.1, 0.1])  # 이미지 정규화
])


for image_path in test_path['image_path']:
    image = Image.open(image_path)
    tensor = transform(image)
    tensor_list_test.append(tensor)

image_tensors_test = torch.stack(tensor_list_test) #test데이터

# %%
X_train = image_tensors_train
y_train = train_data_hairLoss['탈모'].values
X_test = image_tensors_test
y_test = test_data_hairLoss['탈모'].values

# 데이터셋 생성
train_dataset = TensorDataset(X_train, torch.LongTensor(y_train))
test_dataset = TensorDataset(X_test, torch.LongTensor(y_test))

batch_size = 16  # 배치 크기 설정

# 데이터 로더 생성
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
# DenseNet BottleNeck

class BottleNeck(nn.Module):
    def __init__(self, in_channels, growth_rate):
        super().__init__()
        inner_channels = 4 * growth_rate

        self.residual = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(),
            nn.Conv2d(in_channels, inner_channels, 1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(inner_channels),
            nn.ReLU(),
            nn.Conv2d(inner_channels, growth_rate, 3, stride=1, padding=1, bias=False)
        )

        self.shortcut = nn.Sequential()

    def forward(self, x):
        return torch.cat([self.shortcut(x), self.residual(x)], 1)

# %%
# Transition Block: 피쳐맵 크기와 채널 수 감소

class Transition(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()

        self.down_sample = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(),
            nn.Conv2d(in_channels, out_channels, 1, stride=1, padding=0, bias=False),
            nn.AvgPool2d(2, stride=2)
        )

    def forward(self, x):
        return self.down_sample(x)

# %%
# DenseNet

class DenseNet(nn.Module):
    def __init__(self, nblocks, growth_rate=12, reduction=0.5, num_classes=4, init_weights=True):
        super().__init__()

        self.growth_rate = growth_rate
        inner_channels = 2 * growth_rate # output channels of conv1 before entering Dense Block

        self.conv1 = nn.Sequential(
            nn.Conv2d(3, inner_channels, 7, stride=2, padding=3),
            nn.MaxPool2d(3, 2, padding=1)
        )

        self.features = nn.Sequential()

        for i in range(len(nblocks)-1):
            self.features.add_module('dense_block_{}'.format(i), self._make_dense_block(nblocks[i], inner_channels))
            inner_channels += growth_rate * nblocks[i]
            out_channels = int(reduction * inner_channels)
            self.features.add_module('transition_layer_{}'.format(i), Transition(inner_channels, out_channels))
            inner_channels = out_channels 
        
        self.features.add_module('dense_block_{}'.format(len(nblocks)-1), self._make_dense_block(nblocks[len(nblocks)-1], inner_channels))
        inner_channels += growth_rate * nblocks[len(nblocks)-1]
        self.features.add_module('bn', nn.BatchNorm2d(inner_channels))
        self.features.add_module('relu', nn.ReLU())

        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))
        self.linear = nn.Linear(inner_channels, num_classes)

        # weight initialization
        if init_weights:
            self._initialize_weights()
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.features(x)
        x = self.avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        return x

    def _make_dense_block(self, nblock, inner_channels):
        dense_block = nn.Sequential()
        for i in range(nblock):
            dense_block.add_module('bottle_neck_layer_{}'.format(i), BottleNeck(inner_channels, self.growth_rate))
            inner_channels += self.growth_rate
        return dense_block

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

def DenseNet_121():
    return DenseNet([6, 12, 24, 6])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = DenseNet_121()
model.to(device)

# %%
# define loss function, optimizer, lr_scheduler
loss_func = nn.CrossEntropyLoss(reduction='sum')
opt = optim.Adam(model.parameters(), lr=0.001)

from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.1, patience=8)


# get current lr
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']


# calculate the metric per mini-batch
def metric_batch(output, target):
    pred = output.argmax(1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects


# calculate the loss per mini-batch
def loss_batch(loss_func, output, target, opt=None):
    loss_b = loss_func(output, target)
    metric_b = metric_batch(output, target)

    if opt is not None:
        opt.zero_grad()
        loss_b.backward()
        opt.step()
    
    return loss_b.item(), metric_b


# calculate the loss per epochs
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        output = model(xb)

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)

        running_loss += loss_b
        
        if metric_b is not None:
            running_metric += metric_b

        if sanity_check is True:
            break

    loss = running_loss / len_data
    metric = running_metric / len_data
    return loss, metric


# function to start training
def train_val(model, params):
    num_epochs=params['num_epochs']
    loss_func=params['loss_func']
    opt=params['optimizer']
    train_dl=params['train_dl']
    val_dl=params['val_dl']
    sanity_check=params['sanity_check']
    lr_scheduler=params['lr_scheduler']
    #path2weights=params['path2weights']

    loss_history = {'train': [], 'val': []}
    metric_history = {'train': [], 'val': []}

    best_loss = float('inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    start_time = time.time()

    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr= {}'.format(epoch+1, num_epochs, current_lr))

        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss)
        metric_history['train'].append(train_metric)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)
        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            #torch.save(model.state_dict(), path2weights)
            print('Copied best model weights!')

        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print('Loading best model weights!')
            model.load_state_dict(best_model_wts)

        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
# define the training parameters
params_train = {
    'num_epochs':30,
    'optimizer':opt,
    'loss_func':loss_func,
    'train_dl':train_loader,
    'val_dl':test_loader,
    'sanity_check':False,
    'lr_scheduler':lr_scheduler
    #'path2weights':'./models/weights.pt',
}

# %%
model, loss_hist, metric_hist = train_val(model, params_train)
# Out:
# Epoch 1/10, current lr= 0.01
# Copied best model weights!
# train loss: 0.690747, val loss: 0.654698, accuracy: 73.70, time: 0.8086 min
# ----------
# Epoch 2/10, current lr= 0.01
# Copied best model weights!
# train loss: 0.647879, val loss: 0.640843, accuracy: 75.38, time: 1.6141 min
# ----------
# Epoch 3/10, current lr= 0.01
# train loss: 0.643436, val loss: 0.660212, accuracy: 72.33, time: 2.4196 min
# ----------
# Epoch 4/10, current lr= 0.01
# Copied best model weights!
# train loss: 0.637789, val loss: 0.620426, accuracy: 75.51, time: 3.2250 min
# ----------
# Epoch 5/10, current lr= 0.01
# train loss: 0.632867, val loss: 0.650792, accuracy: 74.77, time: 4.0302 min
# ----------
# Epoch 6/10, current lr= 0.01
# train loss: 0.625329, val loss: 0.709284, accuracy: 72.77, time: 4.8435 min
# ----------
# Epoch 7/10, current lr= 0.01
# Copied best model weights!
# train loss: 0.625950, val loss: 0.608041, accuracy: 75.25, time: 5.6518 min
# ----------
# Epoch 8/10, current lr= 0.01
# train loss: 0.618588, val loss: 0.623315, accuracy: 75.00, time: 6.4595 min
# ----------
# Epoch 9/10, current lr= 0.01
# train loss: 0.617546, val loss: 0.638121, accuracy: 73.03, time: 7.2635 min
# ----------
# Epoch 10/10, current lr= 0.01
# train loss: 0.614576, val loss: 0.627388, accuracy: 74.91, time: 8.0658 min
# ----------

# %%
# Train-Validation progress
num_epochs = params_train['num_epochs']

# plot loss progress
plt.title('Accuracy & Loss')
plt.plot(range(1, num_epochs+1), loss_hist['train'], label='train_loss')
plt.plot(range(1, num_epochs+1), loss_hist['val'], label='test_loss')
plt.plot(range(1, num_epochs+1), metric_hist['train'], label='train_accuracy')
plt.plot(range(1, num_epochs+1), metric_hist['val'], label='test_accuracy')
plt.xlabel('Training Epochs')
plt.ylim(0, 1)
plt.legend()
plt.show()
# Out:
# "# plot accuracy progress\nplt.title('Train-Val Accuracy')\nplt.plot(range(1, num_epochs+1), metric_hist['train'], label='train_accuracy')\nplt.plot(range(1, num_epochs+1), metric_hist['val'], label='val_accuracy')\nplt.ylabel('Accuracy')\nplt.xlabel('Training Epochs')\nplt.legend()\nplt.show()"

# %%
torch.save(model, './my_model/model1.pth')
